# %%
from num_loops import num_loops

import networkx as nx

# %%
G = nx.Graph()
G.add_edge(0, 1)
G.add_edge(1, 2)
G.add_edge(2, 0)
nx.draw(G, pos=nx.spring_layout(G), with_labels = True)
num_loops(G)
# Out:
# 12

# %%
G = nx.Graph()
nx.draw(G, pos=nx.spring_layout(G), with_labels = True)
num_loops(G)
# Out:
# 0

# %%
G = nx.Graph()
G.add_edge(0, 1)
G.add_edge(1, 2)
G.add_edge(2, 0)
G.add_edge(3, 0)
nx.draw(G, pos=nx.spring_layout(G), with_labels = True)
num_loops(G)
# Out:
# 50

# %% [markdown]
# # Report
#
# Cycle is a trail (sequence of non-repeating directed edges) with the first and last node the same.
# The number of cycles in the undirected graph is exponential wrt the number of nodes (making the algorithm intracrable for large graphs).
